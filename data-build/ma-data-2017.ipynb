# %%
if (!require("pacman")) install.packages("pacman")
pacman::p_load(tidyverse, ggplot2, dplyr, lubridate, stringr, readxl, data.table, gdata, scales, data.table)

source("functions.R")
monthlist <- sprintf("%02d", 1:12)
y <- 2017
# Out:
# Loading required package: pacman

# %%
# Enrollment & Contract Data
plan.data <- map_dfr(monthlist, ~ load_month(.x, y)) %>%
  arrange(contractid, planid, state, county, month) %>%
  group_by(state, county) %>%
  fill(fips, .direction = "downup") %>%                
  ungroup() %>%
  group_by(contractid, planid) %>%
  fill(plan_type, partd, snp, eghp, plan_name, .direction = "downup") %>%
  ungroup() %>%
  group_by(contractid) %>%
  fill(org_type, org_name, org_marketing_name, parent_org, .direction = "downup") %>%
  ungroup()

plan.data.dt <- as.data.table(plan.data)
setorder(plan.data.dt, contractid, planid, fips, year, month)
  
plan.year <- plan.data.dt[
, {
    nonmiss <- !is.na(enrollment)
    n <- sum(nonmiss)
    list(
      n_nonmiss = n,
      avg_enrollment = if (n>0) mean(enrollment[nonmiss]) else NA_real_,
      state  = tail(state, 1),
      county = tail(county, 1),
      org_type = tail(org_type, 1),
      plan_type = tail(plan_type, 1),
      partd = tail(partd, 1),
      snp   = tail(snp, 1),
      eghp  = tail(eghp, 1),
      org_name = tail(org_name, 1),
      org_marketing_name = tail(org_marketing_name, 1),
      plan_name = tail(plan_name, 1),
      parent_org = tail(parent_org, 1),
      contract_date = tail(contract_date, 1)
    )
  },
by = .(contractid, planid, fips, year)
]

plan.data.2017 <- as_tibble(plan.year)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”

# %%
# Service Area Data
service.year <- map_dfr(monthlist, ~ load_month_sa(.x, y))

# Ensure stable order before fills
service.year <- service.year %>%
  arrange(contractid, fips, state, county, month)

# Fill missing identifiers/labels
service.year <- service.year %>%
  group_by(state, county) %>%
  fill(fips, .direction = "downup") %>%
  ungroup() %>%
  group_by(contractid) %>%
  fill(plan_type, partial, eghp, org_type, org_name, .direction = "downup") %>%
  ungroup()

# Collapse to yearly: one row per contract × county (fips) × year --------
service.data.2017 <- service.year %>%
  group_by(contractid, fips, year) %>%
  arrange(month, .by_group = TRUE) %>%
  summarize(
    state     = last(state),
    county    = last(county),
    org_name  = last(org_name),
    org_type  = last(org_type),
    plan_type = last(plan_type),
    partial   = last(partial),
    eghp      = last(eghp),
    ssa       = last(ssa),
    notes     = last(notes),
    .groups = "drop"
  )

rm(service.year)
gc()
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells   1085170   58.0    5462388   291.8    6827984  364.7
# Vcells 980340919 7479.5 1816178282 13856.4 1264744538 9649.3

# %%
# Plan Characteristics (premium) data

ma.path.a <- paste0("../../ma-data/ma/landscape/Extracted Data/2017LandscapeSource file MA_AtoM 10182016.csv")
ma.data.a <- read_csv(ma.path.a,
                      skip=6,
                      col_names=c("state","county","org_name","plan_name","plan_type","premium","partd_deductible",
                                  "drug_type","gap_coverage","drug_type_detail","contractid",
                                  "planid","segmentid","moop","star_rating"),
                      col_types = cols(
                        state = col_character(),
                        county = col_character(),
                        org_name = col_character(),
                        plan_name = col_character(),
                        plan_type = col_character(),
                        premium = col_number(),
                        partd_deductible = col_number(),
                        drug_type = col_character(),
                        gap_coverage = col_character(),
                        drug_type_detail = col_character(),
                        contractid = col_character(),
                        planid = col_double(),
                        segmentid = col_double(),
                        moop = col_character(),
                        star_rating = col_character()
                      ))


ma.path.b <- paste0("../../ma-data/ma/landscape/Extracted Data/2017LandscapeSource file MA_NtoW 10182016.csv")
ma.data.b <- read_csv(ma.path.b,
                      skip=6,
                      col_names=c("state","county","org_name","plan_name","plan_type","premium","partd_deductible",
                                  "drug_type","gap_coverage","drug_type_detail","contractid",
                                  "planid","segmentid","moop","star_rating"),
                      col_types = cols(
                        state = col_character(),
                        county = col_character(),
                        org_name = col_character(),
                        plan_name = col_character(),
                        plan_type = col_character(),
                        premium = col_number(),
                        partd_deductible = col_number(),
                        drug_type = col_character(),
                        gap_coverage = col_character(),
                        drug_type_detail = col_character(),
                        contractid = col_character(),
                        planid = col_double(),
                        segmentid = col_double(),
                        moop = col_character(),
                        star_rating = col_character()
                      ))

ma.data <- rbind(ma.data.a,ma.data.b)


mapd.path.a <- paste0("../../ma-data/ma/landscape/Extracted Data/PartCD/2017/Medicare Part D 2017 Plan Report 10182016.xls")
mapd.data.a <- read_xls(mapd.path.a,
                        range="A5:Z17657",
                        sheet="Alabama to Montana",
                        col_names=c("state","county","org_name","plan_name","contractid","planid","segmentid",
                                    "org_type","plan_type","snp","snp_type","benefit_type","below_benchmark",
                                    "national_pdp","premium_partc",
                                    "premium_partd_basic","premium_partd_supp","premium_partd_total",
                                    "partd_assist_full","partd_assist_75","partd_assist_50","partd_assist_25",
                                    "partd_deductible","deductible_exclusions","increase_coverage_limit",
                                    "gap_coverage"))



mapd.path.b <- paste0("../../ma-data/ma/landscape/Extracted Data/PartCD/2017/Medicare Part D 2017 Plan Report 10182016.xls")
mapd.data.b <- read_xls(mapd.path.b,
                        range="A5:Z20217",
                        sheet="Nebraska to Wyoming",
                        col_names=c("state","county","org_name","plan_name","contractid","planid","segmentid",
                                    "org_type","plan_type","snp","snp_type","benefit_type","below_benchmark",
                                    "national_pdp","premium_partc",
                                    "premium_partd_basic","premium_partd_supp","premium_partd_total",
                                    "partd_assist_full","partd_assist_75","partd_assist_50","partd_assist_25",
                                    "partd_deductible","deductible_exclusions","increase_coverage_limit",
                                    "gap_coverage"))
mapd.data <- rbind(mapd.data.a,mapd.data.b)

# Combine and Clean dollar signs/commas
mapd.data <- rbind(mapd.data.a, mapd.data.b) %>%
  mutate(across(contains("premium") | contains("partd"), ~parse_number(as.character(.))))

landscape.2017 <- mapd.clean.merge(ma.data=ma.data, mapd.data=mapd.data, y)
# Out:
# Warning message:
# “Expecting numeric in O1555 / R1555C15: got '$75.50'”
# Warning message:
# “Coercing text to numeric in X1555 / R1555C24: '1'”
# Warning message:
# “Expecting numeric in O1567 / R1567C15: got '$24.50'”
# Warning message:
# “Coercing text to numeric in X1567 / R1567C24: '1'”
# Warning message:
# “Expecting numeric in O1573 / R1573C15: got '$75.50'”
# Warning message:
# “Coercing text to numeric in X1573 / R1573C24: '1'”
# Warning message:
# “Expecting numeric in O1583 / R1583C15: got '$24.50'”
# Warning message:
# “Coercing text to numeric in X1583 / R1583C24: '1'”
# Warning message:
# “Expecting numeric in O1589 / R1589C15: got '$46.80'”
# Warning message:
# “Coercing text to numeric in X1589 / R1589C24: '1'”
# Warning message:
# “Expecting numeric in O1593 / R1593C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1593 / R1593C24: '1'”
# Warning message:
# “Expecting numeric in O1594 / R1594C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1613 / R1613C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1619 / R1619C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1619 / R1619C24: '1'”
# Warning message:
# “Expecting numeric in O1620 / R1620C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1667 / R1667C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1668 / R1668C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1669 / R1669C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1702 / R1702C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1703 / R1703C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1704 / R1704C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1704 / R1704C24: '1'”
# Warning message:
# “Expecting numeric in O1803 / R1803C15: got '$46.80'”
# Warning message:
# “Coercing text to numeric in X1803 / R1803C24: '1'”
# Warning message:
# “Expecting numeric in O1819 / R1819C15: got '$24.50'”
# Warning message:
# “Coercing text to numeric in X1819 / R1819C24: '1'”
# Warning message:
# “Expecting numeric in O1821 / R1821C15: got '$24.50'”
# Warning message:
# “Coercing text to numeric in X1821 / R1821C24: '1'”
# Warning message:
# “Expecting numeric in O1833 / R1833C15: got '$75.80'”
# Warning message:
# “Coercing text to numeric in X1833 / R1833C24: '1'”
# Warning message:
# “Expecting numeric in O1841 / R1841C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1842 / R1842C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1843 / R1843C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1861 / R1861C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1862 / R1862C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1863 / R1863C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1863 / R1863C24: '1'”
# Warning message:
# “Expecting numeric in O1908 / R1908C15: got '$59.40'”
# Warning message:
# “Coercing text to numeric in X1908 / R1908C24: '1'”
# Warning message:
# “Expecting numeric in O1909 / R1909C15: got '$0.50'”
# Warning message:
# “Coercing text to numeric in X1909 / R1909C24: '1'”
# Warning message:
# “Expecting numeric in O1917 / R1917C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1918 / R1918C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1919 / R1919C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1927 / R1927C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1928 / R1928C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1929 / R1929C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1929 / R1929C24: '1'”
# Warning message:
# “Expecting numeric in O1971 / R1971C15: got '$59.40'”
# Warning message:
# “Coercing text to numeric in X1971 / R1971C24: '1'”
# Warning message:
# “Expecting numeric in O1972 / R1972C15: got '$0.50'”
# Warning message:
# “Coercing text to numeric in X1972 / R1972C24: '1'”
# Warning message:
# “Expecting numeric in O1974 / R1974C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X1974 / R1974C24: '1'”
# Warning message:
# “Expecting numeric in O1975 / R1975C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1990 / R1990C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1991 / R1991C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O1992 / R1992C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2007 / R2007C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2008 / R2008C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2009 / R2009C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X2009 / R2009C24: '1'”
# Warning message:
# “Expecting numeric in O2055 / R2055C15: got '$0.50'”
# Warning message:
# “Expecting numeric in O2056 / R2056C15: got '$29.90'”
# Warning message:
# “Expecting numeric in O2057 / R2057C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2058 / R2058C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2062 / R2062C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2063 / R2063C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X2063 / R2063C24: '1'”
# Warning message:
# “Expecting numeric in O2093 / R2093C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X2093 / R2093C24: '1'”
# Warning message:
# “Expecting numeric in O2094 / R2094C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2114 / R2114C15: got '$10.30'”
# Warning message:
# “Coercing text to numeric in X2114 / R2114C24: '1'”
# Warning message:
# “Expecting numeric in O2120 / R2120C15: got '$75.50'”
# Warning message:
# “Coercing text to numeric in X2120 / R2120C24: '1'”
# Warning message:
# “Expecting numeric in O2123 / R2123C15: got '$10.30'”
# Warning message:
# “Coercing text to numeric in X2123 / R2123C24: '1'”
# Warning message:
# “Expecting numeric in O2129 / R2129C15: got '$75.40'”
# Warning message:
# “Coercing text to numeric in X2129 / R2129C24: '1'”
# Warning message:
# “Expecting numeric in O2158 / R2158C15: got '$0.50'”
# Warning message:
# “Coercing text to numeric in X2158 / R2158C24: '1'”
# Warning message:
# “Expecting numeric in O2166 / R2166C15: got '$65.70'”
# Warning message:
# “Coercing text to numeric in X2166 / R2166C24: '1'”
# Warning message:
# “Expecting numeric in O2167 / R2167C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X2167 / R2167C24: '1'”
# Warning message:
# “Expecting numeric in O2191 / R2191C15: got '$24.50'”
# Warning message:
# “Coercing text to numeric in X2191 / R2191C24: '1'”
# Warning message:
# “Expecting numeric in O2201 / R2201C15: got '$12.30'”
# Warning message:
# “Coercing text to numeric in X2201 / R2201C24: '1'”
# Warning message:
# “Expecting numeric in O2202 / R2202C15: got '$0.00'”
# Warning message:
# “Coercing text to numeric in X2202 / R2202C24: '1'”
# Warning message:
# “Expecting numeric in O2203 / R2203C15: got '$0.00'”
# Warning message:
# “Expecting numeric in O2214 / R2214C15: got '$59.40'”
# Warning message:
# “Coercing text to numeric in X2214 / R2214C24: '1'”
# Warning message:
# “Expecting numeric in O2215 / R2215C15: got '$0.50'”
# Warning message:
# “Coercing text to numeric in X2215 / R2215C24: '1'”
# Warning message:
# “Expecting numeric in O2218 / R2218C15: got '$0.00'”
# Warning message:
# “Expecting logical in Y3871 / R3871C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3882 / R3882C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3888 / R3888C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3890 / R3890C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3893 / R3893C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3900 / R3900C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3908 / R3908C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3911 / R3911C25: got 'Y'”
# Warning message:
# “Expecting logical in Y3914 / R3914C25: got 'Y'”
# Warning message:
# “Expecting numeric in O12190 / R12190C15: got '$0.00'”

# %%
# Penetration Data
ma.penetration <- map_dfr(monthlist, ~ load_month_pen(.x, y)) %>%
  arrange(state, county, month) %>%
  group_by(state, county) %>%
  fill(fips, .direction = "downup") %>%
  ungroup()

# Collapse to yearly (safe summaries; avoid NaN/Inf) ----------------------
pen.2017 <- ma.penetration %>%
  group_by(fips, state, county, year) %>%
  arrange(month, .by_group = TRUE) %>%
  summarize(
    n_elig  = sum(!is.na(eligibles)),
    n_enrol = sum(!is.na(enrolled)),

    avg_eligibles   = ifelse(n_elig  > 0, mean(eligibles, na.rm = TRUE), NA_real_),
    sd_eligibles    = ifelse(n_elig  > 1,  sd(eligibles,  na.rm = TRUE), NA_real_),
    min_eligibles   = ifelse(n_elig  > 0, min(eligibles,  na.rm = TRUE), NA_real_),
    max_eligibles   = ifelse(n_elig  > 0, max(eligibles,  na.rm = TRUE), NA_real_),
    first_eligibles = ifelse(n_elig  > 0, first(na.omit(eligibles)),     NA_real_),
    last_eligibles  = ifelse(n_elig  > 0,  last(na.omit(eligibles)),     NA_real_),

    avg_enrolled    = ifelse(n_enrol > 0, mean(enrolled,   na.rm = TRUE), NA_real_),
    sd_enrolled     = ifelse(n_enrol > 1,  sd(enrolled,    na.rm = TRUE), NA_real_),
    min_enrolled    = ifelse(n_enrol > 0, min(enrolled,    na.rm = TRUE), NA_real_),
    max_enrolled    = ifelse(n_enrol > 0, max(enrolled,    na.rm = TRUE), NA_real_),
    first_enrolled  = ifelse(n_enrol > 0, first(na.omit(enrolled)),       NA_real_),
    last_enrolled   = ifelse(n_enrol > 0,  last(na.omit(enrolled)),       NA_real_),

    ssa = last(ssa),
    .groups = "drop"
  )

# %%
# Rebate Data
ma.path.a <- "../../ma-data/ma/cms-payment/2017/2017PartCPlanLevel.xlsx"
risk.rebate.a <- read_xlsx(ma.path.a,range="A4:G2813",
                        col_names=c("contractid","planid","contract_name","plan_type",
                                    "riskscore_partc","payment_partc","rebate_partc"))
ma.path.b <- "../../ma-data/ma/cms-payment/2017/2017PartDPlans.xlsx"
risk.rebate.b <- read_xlsx(ma.path.b,range="A4:H3606",
                        col_names=c("contractid","planid","contract_name","plan_type",
                                    "directsubsidy_partd","riskscore_partd","reinsurance_partd",
                                    "costsharing_partd"))


risk.rebate.a <- risk.rebate.a %>%
  mutate(
    across(c(riskscore_partc, payment_partc, rebate_partc),
           ~ parse_number(as.character(.))),
    planid = as.numeric(planid),
    year   = 2017
  ) %>%
  select(contractid, planid, contract_name, plan_type,
         riskscore_partc, payment_partc, rebate_partc, year)    

risk.rebate.b <- risk.rebate.b %>%
  mutate(
    across(c(directsubsidy_partd, reinsurance_partd, costsharing_partd),
           ~ parse_number(as.character(.))),
    payment_partd = directsubsidy_partd + reinsurance_partd + costsharing_partd,
    planid        = as.numeric(planid)
  ) %>%
  select(contractid, planid, payment_partd,
         directsubsidy_partd, reinsurance_partd, costsharing_partd,
         riskscore_partd)  
  
rebate.2017 <- risk.rebate.a %>%
  left_join(risk.rebate.b, by=c("contractid","planid"))

# %%
# FFS Cost Data
ffs.data <- read_xlsx("../../ma-data/ffs-costs/Extracted Data/ffs2017/FFS17.xlsx",
                  skip=2,
                  col_names=c("ssa","state","county_name","parta_enroll",
                              "parta_reimb","parta_percap","parta_reimb_unadj",
                              "parta_percap_unadj","parta_ime","parta_dsh",
                              "parta_gme","partb_enroll",
                              "partb_reimb","partb_percap"), na="*")


ffscosts.2017 <- ffs.data %>%
  select(ssa,state,county_name,parta_enroll,parta_reimb,
         partb_enroll,partb_reimb) %>%
  mutate(year=2017,
         ssa=as.numeric(ssa),
         mean_risk=NA) %>%
  mutate(across(c(parta_enroll, parta_reimb, partb_enroll, partb_reimb, mean_risk),
              ~ parse_number(as.character(.))))
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `ssa = as.numeric(ssa)`.
# Caused by warning:
# ! NAs introduced by coercion”

# %%
# Merge
ma.2017 <- plan.data.2017 %>%
  inner_join(service.data.2017 %>% select(contractid, fips),
             by = c("contractid","fips")) %>%
  filter(!state %in% c("VI","PR","MP","GU","AS",""),
         snp == "No",
         (planid < 800 | planid >= 900),
         !is.na(planid), !is.na(fips)) %>%
  left_join(pen.2017 %>% ungroup() %>% rename(state_long = state, county_long = county) %>%
            mutate(state_long=str_to_lower(state_long)) %>% 
            group_by(fips) %>% mutate(ncount=n()) %>% filter(ncount==1),
            by = c("fips"))

state.2017 <- ma.2017 %>%
  group_by(state) %>%
  summarize(state_name = last(state_long[!is.na(state_long)]), .groups = "drop")

st_crosswalk <- tibble(
  state_abb = c(state.abb, "DC"), 
  state_full = toupper(c(state.name, "District of Columbia"))
)

# 2. Run the full merge with cleaning
full.2017 <- ma.2017 %>%
  left_join(state.2017, by = "state") %>%
  left_join(landscape.2017 %>% mutate(state=str_to_lower(state)), by = c("contractid","planid","state_name" = "state","county")) %>%
  left_join(rebate.2017 %>% select(-contract_name, -plan_type), by = c("contractid","planid")) %>%
  mutate(
    year = 2017,
    ssa = as.numeric(ssa)
  ) %>%
  mutate(across(c(premium, premium_partc, rebate_partc, payment_partc, riskscore_partc), 
                ~ parse_number(as.character(.)))) %>%
  mutate(
    basic_premium = case_when(
      rebate_partc > 0 ~ 0,
      partd == "No" & !is.na(premium) & is.na(premium_partc) ~ premium,
      TRUE ~ premium_partc
    ),
    bid = case_when(
      rebate_partc == 0 & basic_premium > 0 ~ (payment_partc + basic_premium) / riskscore_partc,
      rebate_partc > 0  | basic_premium == 0 ~  payment_partc / riskscore_partc,
      TRUE ~ NA_real_
    )
  ) %>% 
  left_join(ffscosts.2017 %>% select(-state) %>% filter(!is.na(ssa)), by = c("ssa","year")) %>%
  mutate(
    avg_ffscost = case_when(
      parta_enroll == 0 & partb_enroll == 0 ~ 0,
      parta_enroll == 0 & partb_enroll >  0 ~ partb_reimb / partb_enroll,
      parta_enroll >  0 & partb_enroll == 0 ~ parta_reimb / parta_enroll,
      parta_enroll >  0 & partb_enroll >  0 ~ (parta_reimb / parta_enroll) + (partb_reimb / partb_enroll),
      TRUE ~ NA_real_
    )
  )

# %%
# Create CSV in data output folder
write_csv(full.2017,"../data/output/data-2017.csv")

# %%
# --- FINAL MATCH AUDIT ---
audit_matches <- tibble(
  Stage = c("Landscape (Premiums)", "Rebate (Bids)", "FFS Costs"),
  Matched_Count = c(
    sum(!is.na(full.2017$premium)),
    sum(!is.na(full.2017$rebate_partc)),
    sum(!is.na(full.2017$avg_ffscost))
  )
) %>%
  mutate(Match_Rate = Matched_Count / nrow(full.2017))

print(audit_matches)
# Out:
# # A tibble: 3 × 3
#   Stage                Matched_Count Match_Rate
#   <chr>                        <int>      <dbl>
# 1 Landscape (Premiums)         32887      0.462
# 2 Rebate (Bids)                64392      0.904
# 3 FFS Costs                    71170      0.999
